# %% [markdown]
# <a href="https://colab.research.google.com/github/tabiicodes/AI-Labspace/blob/main/tayyaba_lab4_9sep26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get("STUDIO_API_KEY"))

MODEL = "models/gemini-3.5-flash"


professors = {
    "artificial intelligence": "Dr. Uzma Afzal",
    "database systems": "Dr. Uzma Afzal",
    "computer networks": "Maam Asma",
    "software engineering": "Dr. Kashif"
}


def university_agent(user_input):

    for course in professors:
        if course in user_input.lower():
            return "Professor: " + professors[course]

    if "professor" in user_input.lower() or "teacher" in user_input.lower():
        return "No information found in the available data."

    prompt = f"""
You are a helpful AI assistant for Federal Urdu University
of Arts, Science and Technology.

Answer the user's general question in a simple and clear way.

User question: {user_input}

Answer:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("FUUAST AI Assistant Started (type 'exit' to stop)\n")

while True:

    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = university_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# FUUAST AI Assistant Started (type 'exit' to stop)
#
# You: how many campus are there in karachi
#
# Agent:
#  Welcome to the Federal Urdu University of Arts, Science and Technology (FUUAST)!
#
# There are **two (2)** campuses of FUUAST located in Karachi:
#
# 1. **Gulshan-e-Iqbal Campus (Main Campus):** Located on University Road, this campus mainly hosts the faculties of Science, Technology, and Business Administration.
# 2. **Abdul Haq Campus (Baba-e-Urdu Road):** Located near the Civil Hospital in old city area, this campus mainly hosts the faculties of Arts, Languages, Social Sciences, Law, and Commerce.
#
# *(Note: There is also a third campus of FUUAST, which is located in Islamabad).*
#
# Please let me know if you need directions or information about any specific department!
#
# You: tell me about the artificial intelligence professor name
#
# Agent:
#  Professor: Dr. Uzma Afzal
#
# You: what about operating system professor
#
# Agent:
# ...
