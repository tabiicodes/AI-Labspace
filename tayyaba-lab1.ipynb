# %% [markdown]
# <a href="https://colab.research.google.com/github/tabiicodes/AI-Labspace/blob/main/tayyaba-lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### AI Travel Agent
# ##### Lab 1
# ##### Student: Tayyaba Irshad
# This program acts as a simple Travel Agent.
# It asks the user for their destination, budget, and travel preference,then recommends a suitable travel plan.

# %%
print("AI TRAVEL AGENT")

name = input("Enter your name: ")
destination = input("Enter your destination: ")
budget = float(input("Enter your budget (PKR): "))

print("\nChoose your travel preference:")
print("1. Budget")
print("2. Comfortable")
print("3. Luxury")

preference = input("Enter your choice (1-3): ")

# Agent decision-making
if preference == "1":
     hotel = "Budget Hotel"
     transport = "Public Transport"

elif preference == "2":
     hotel = "3-Star Hotel"
     transport = "Private/Shared Transport"

elif preference == "3":
     hotel = "5-Star Hotel"
     transport = "Private Car"

else:
     print("Invalid preference. Defaulting to Budget plan.")
     hotel = "Budget Hotel"
     transport = "Public Transport"

# Budget evaluation
if budget < 50000:
   budget_status = "Low budget"
elif budget <= 150000:
   budget_status = "Medium budget"
else:
   budget_status = "High budget"

# Final recommendation
print("\nTRAVEL PLAN")
print(f"\nTraveler: {name}")
print(f"Destination: {destination}")
print(f"Budget: PKR {budget:,.0f}")
print(f"Budget Category: {budget_status}")
print(f"Hotel: {hotel}")
print(f"Transport: {transport}")

print("\nTravel Agent: Plan generated successfully!")
# Out:
# AI TRAVEL AGENT
# Enter your name: Tayyaba
# Enter your destination: Malaysia
# Enter your budget (PKR): 150000
#
# Choose your travel preference:
# 1. Budget
# 2. Comfortable
# 3. Luxury
# Enter your choice (1-3): 2
#
# TRAVEL PLAN
#
# Traveler: Tayyaba
# Destination: Malaysia
# Budget: PKR 150,000
# Budget Category: Medium budget
# Hotel: 3-Star Hotel
# Transport: Private/Shared Transport
#
# Travel Agent: Plan generated successfully!
